# %% [markdown]
# # Exercise 2

# %% [markdown]
# ## Data loading and examination

# %%
import pandas as pd
import sqlite3
with sqlite3.connect("hw1-population.db") as db:
    data = pd.read_sql_query("SELECT * FROM population", db)

# %%
data.head()
# Out:
#             name        age     weight eyecolor
# 0    Edna Phelps  88.895690  67.122450    brown
# 1     Cara Yasso   9.274597  29.251244    brown
# 2      Gail Rave  18.345613  55.347903    brown
# 3  Richard Adams  16.367545  70.352184    brown
# 4  Krista Slater  49.971604  70.563859    brown

# %%
print("The data has the following columns:", list(data.columns))
# Out:
# The data has the following columns: ['name', 'age', 'weight', 'eyecolor']

# %%
print("The data has", data.shape[0], "rows.")
# Out:
# The data has 152361 rows.

# %% [markdown]
# ## Analysis of age

# %%
data[['age']].describe()
# Out:
#                  age
# count  152361.000000
# mean       39.510528
# std        24.152760
# min         0.000748
# 25%        19.296458
# 50%        38.468955
# 75%        57.623245
# max        99.991547

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plt.hist(data['age'], bins=20, rwidth=0.745, color='b', alpha=0.8)
plt.xticks(np.arange(0,110,10), fontsize=15)
plt.yticks(np.arange(0,11000,1000), fontsize=15)
plt.xlabel('Age', fontsize=15)
plt.ylabel('Number', fontsize=15)
plt.title('Distribution of age within the population', fontsize=20)
plt.grid()
plt.savefig("README_img/EX2_1.png")
plt.show()

# %% [markdown]
# ## Analysis of Weight

# %%
data[['weight']].describe()
# Out:
#               weight
# count  152361.000000
# mean       60.884134
# std        18.411824
# min         3.382084
# 25%        58.300135
# 50%        68.000000
# 75%        71.529860
# max       100.435793

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plt.hist(data['weight'], bins=20, rwidth=0.745, color='b', alpha=0.8)
plt.xticks(np.arange(0,110,10), fontsize=15)
plt.yticks(np.arange(0,55000,5000), fontsize=15)
plt.xlabel('Weight', fontsize=15)
plt.ylabel('Number', fontsize=15)
plt.title('Distribution of weight within the population', fontsize=20)
plt.grid()
plt.savefig("README_img/EX2_2.png")
plt.show()

# %% [markdown]
# ## Analysis of Weight vs. Age

# %%
plt.figure(figsize=(20,10))
plt.scatter(list(data['age']), list(data['weight']), s=0.75)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Age', fontsize=15)
plt.ylabel('Weight', fontsize=15)
plt.title('The scatterplot of Age vs. Weight', fontsize=20)
plt.savefig("README_img/EX2_3.png")
plt.show()

# %% [markdown]
# I find that there is a person who is roughly 41 years old but the weight is rarely small. So the person is sorted out by the following codes.

# %%
age_sort = data[data['age'] > 40]
outlier = age_sort[age_sort['weight'] < 30]
print("The name of the outlier person is", outlier['name'].iloc[0])
outlier
# Out:
# The name of the outlier person is Anthony Freeman
#                 name   age  weight eyecolor
# 537  Anthony Freeman  41.3    21.7    green
